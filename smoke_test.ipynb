# %%
import idaes
from pyomo.environ import ConcreteModel, SolverFactory
import idaes.logger as idaeslog

# Check version
print("IDAES version:", idaes.__version__)

# Check IPOPT solver
solver = SolverFactory("ipopt")
print("IPOPT available:", solver.available())
# Out:
# IDAES version: 2.11.0
# IPOPT available: True

# %%
# Step 0 — Verify all MAPIRL-DT imports work

import idaes
print('IDAES:', idaes.__version__)  # must say 2.11.0

from idaes.models_extra.power_generation.unit_models.soec_design import SoecDesign
from idaes.models_extra.power_generation.properties.natural_gas_PR import get_prop, EosType

print('All imports OK')
# Out:
# IDAES: 2.11.0
# All imports OK

# %%
from pyomo.environ import ConcreteModel, SolverFactory, value, TransformationFactory
from idaes.core import FlowsheetBlock
from idaes.models_extra.power_generation.unit_models.soec_design import SoecDesign
from idaes.models_extra.power_generation.properties.natural_gas_PR import get_prop, EosType
from idaes.models.properties.modular_properties.base.generic_property import GenericParameterBlock

m = ConcreteModel()
m.fs = FlowsheetBlock(dynamic=False)
print("Flowsheet built OK")
# Out:
# Flowsheet built OK

# %%
# Cathode (hydrogen side): H2O + H2
m.fs.prop_h2 = GenericParameterBlock(
    **get_prop({"H2O", "H2"}, phases={"Vap"}, eos=EosType.IDEAL)
)

# Anode (oxygen side): O2 + H2O sweep gas
m.fs.prop_o2 = GenericParameterBlock(
    **get_prop({"O2", "H2O"}, phases={"Vap"}, eos=EosType.IDEAL)
)
print("Property packages built OK")
# Out:
# Property packages built OK

# %%
m.fs.soec = SoecDesign(
    oxygen_side_property_package=m.fs.prop_o2,
    hydrogen_side_property_package=m.fs.prop_h2,
    has_heat_transfer=True,
)
TransformationFactory("network.expand_arcs").apply_to(m)
print("SoecDesign configured OK")
# Out:
# SoecDesign configured OK

# %%
# Hydrogen side inlet (cathode)
m.fs.soec.hydrogen_side.inlet.temperature[0].fix(1073.15)  # 800°C
m.fs.soec.hydrogen_side.inlet.pressure[0].fix(1.5e5)
m.fs.soec.hydrogen_side.inlet.flow_mol[0].fix(0.10)
m.fs.soec.hydrogen_side.inlet.mole_frac_comp[0, "H2O"].fix(0.90)
m.fs.soec.hydrogen_side.inlet.mole_frac_comp[0, "H2"].fix(0.10)

# Oxygen side inlet (anode)
m.fs.soec.oxygen_side.inlet.temperature[0].fix(1073.15)
m.fs.soec.oxygen_side.inlet.pressure[0].fix(1.5e5)
m.fs.soec.oxygen_side.inlet.flow_mol[0].fix(0.10)
m.fs.soec.oxygen_side.inlet.mole_frac_comp[0, "O2"].fix(0.21)
m.fs.soec.oxygen_side.inlet.mole_frac_comp[0, "H2O"].fix(0.79)

# Design variable
m.fs.soec.water_utilization[0].fix(0.80)

# ⚠️ CRITICAL CHECK — must print 0 before solving
from idaes.core.util.model_statistics import degrees_of_freedom
print("Degrees of freedom:", degrees_of_freedom(m))  # Must be 0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Hydrogen side inlet (cathode)
# ----> 2 m.fs.soec.hydrogen_side.inlet.temperature[0].fix(1073.15)  # 800°C
#       3 m.fs.soec.hydrogen_side.inlet.pressure[0].fix(1.5e5)
#       4 m.fs.soec.hydrogen_side.inlet.flow_mol[0].fix(0.10)
#
# File ~\miniconda3\envs\idaes-env\lib\site-packages\pyomo\core\base\block.py:550, in BlockData.__getattr__(self, val)
#     547     return _component_decorator(self, ModelComponentFactory.get_class(val))
#     548 # Since the base classes don't support getattr, we can just
#     549 # throw the "normal" AttributeError
# --> 550 raise AttributeError(
#     551     "'%s' object has no attribute '%s'" % (self.__class__.__name__, val)
#     552 )
#
# AttributeError: '_ScalarSoecDesign' object has no attribute 'hydrogen_side'

# %%
# Run this BEFORE fixing any variables
from idaes.models_extra.power_generation.unit_models.soec_design import SoecDesign
import inspect, os

# Find where the file actually lives
src_path = inspect.getfile(SoecDesign)
print("Source file:", src_path)

# Print all component names on the built model
print("\n--- All soec attributes ---")
for name in m.fs.soec.component_map():
    print(name)
# Out:
# Source file: C:\Users\LOGIN\miniconda3\envs\idaes-env\lib\site-packages\idaes\models_extra\power_generation\unit_models\soec_design.py
#
# --- All soec attributes ---
# electrolysis_prop_params
# electrolysis_rxn_params
# h2_inlet_translator
# electrolysis_reactor
# o2_separator
# h2_outlet_translator
# o2_translator
# o2_mixer
# sweep_heater
# strm1
# strm2
# strm3
# strm4
# strm5
# strm6
# strm1_expanded
# strm2_expanded
# strm3_expanded
# strm4_expanded
# strm5_expanded
# strm6_expanded
# current
# water_utilization
# cell_potential
# heat
# hydrogen_side_outlet_temperature
# oxygen_side_outlet_temperature
# water_utilization_eqn
# current_expr
# current_eqn
# delta_enth
# cell_potential_eqn
# hydrogen_side_inlet
# _flow_mol_hydrogen_side_inlet_ref
# _mole_frac_comp_hydrogen_side_inlet_ref
# _temperature_hydrogen_side_inlet_ref
# _pressure_hydrogen_side_inlet_ref
# oxygen_side_inlet
# _flow_mol_oxygen_side_inlet_ref
# _mole_frac_comp_oxygen_side_inlet_ref
# _temperature_oxygen_side_inlet_ref
# _pressure_oxygen_side_inlet_ref
# hydrogen_side_outlet
# _flow_mol_hydrogen_side_outlet_ref
# _mole_frac_comp_hydrogen_side_outlet_ref
# _temperature_hydrogen_side_outlet_ref
# _pressure_hydrogen_side_outlet_ref
# oxygen_side_outlet
# _flow_mol_oxygen_side_outlet_ref
# _mole_frac_comp_oxygen_side_outlet_ref
# _temperature_oxygen_side_outlet_ref
# _pressure_oxygen_side_outlet_ref
# scaling_factor

# %%
# Find all inlet/outlet ports
print("\n--- Ports only ---")
from pyomo.network import Port
for name, comp in m.fs.soec.component_map():
    if isinstance(comp, Port):
        print(f"PORT: {name}")
        for var in comp.vars:
            print(f"  .{var}")
# Out:
# --- Ports only ---
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 4
#       2 print("\n--- Ports only ---")
#       3 from pyomo.network import Port
# ----> 4 for name, comp in m.fs.soec.component_map():
#       5     if isinstance(comp, Port):
#       6         print(f"PORT: {name}")
#
# ValueError: too many values to unpack (expected 2)

# %%
# Step 4 — Fix conditions using CORRECT port names (confirmed from component_map)

# Hydrogen side inlet (cathode)
m.fs.soec.hydrogen_side_inlet.flow_mol[0].fix(0.10)
m.fs.soec.hydrogen_side_inlet.mole_frac_comp[0, "H2O"].fix(0.90)
m.fs.soec.hydrogen_side_inlet.mole_frac_comp[0, "H2"].fix(0.10)
m.fs.soec.hydrogen_side_inlet.temperature[0].fix(1073.15)   # 800°C
m.fs.soec.hydrogen_side_inlet.pressure[0].fix(1.5e5)        # 1.5 bar

# Oxygen side inlet (anode)
m.fs.soec.oxygen_side_inlet.flow_mol[0].fix(0.10)
m.fs.soec.oxygen_side_inlet.mole_frac_comp[0, "O2"].fix(0.21)
m.fs.soec.oxygen_side_inlet.mole_frac_comp[0, "H2O"].fix(0.79)
m.fs.soec.oxygen_side_inlet.temperature[0].fix(1073.15)
m.fs.soec.oxygen_side_inlet.pressure[0].fix(1.5e5)

# Design variable — controls effective current density
m.fs.soec.water_utilization[0].fix(0.80)

# ⚠️ MUST print 0 before solving
from idaes.core.util.model_statistics import degrees_of_freedom
print("Degrees of freedom:", degrees_of_freedom(m))
# Out:
# Degrees of freedom: 3

# %%
# Diagnose which variables are free (unfixed)
from idaes.core.util.model_statistics import (
    degrees_of_freedom,
    unfixed_variables_in_activated_equalities
)

print("DOF:", degrees_of_freedom(m))
print("\n--- Unfixed variables ---")
for v in unfixed_variables_in_activated_equalities(m):
    print(v)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Diagnose which variables are free (unfixed)
# ----> 2 from idaes.core.util.model_statistics import (
#       3     degrees_of_freedom,
#       4     unfixed_variables_in_activated_equalities
#       5 )
#       7 print("DOF:", degrees_of_freedom(m))
#       8 print("\n--- Unfixed variables ---")
#
# ImportError: cannot import name 'unfixed_variables_in_activated_equalities' from 'idaes.core.util.model_statistics' (C:\Users\LOGIN\miniconda3\envs\idaes-env\lib\site-packages\idaes\core\util\model_statistics.py)

# %%
# Find the 3 unfixed variables using Pyomo directly
from pyomo.environ import value
import pyomo.environ as pyo

print("--- Unfixed active variables ---")
count = 0
for v in m.component_data_objects(pyo.Var, active=True, descend_into=True):
    if not v.fixed and not v.stale:
        print(v, "=", v.value)
        count += 1
print(f"\nTotal unfixed: {count}")
# Out:
# --- Unfixed active variables ---
# fs.soec.current[0.0] = 0
# fs.soec.cell_potential[0.0] = 1.3
# fs.soec.heat[0.0] = 0
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].temperature = 500
# fs.soec.sweep_heater.control_volume.properties_out[0.0].temperature = 500
# fs.soec.h2_outlet_translator.properties_out[0.0].flow_mol = 8000
# fs.soec.h2_outlet_translator.properties_out[0.0].mole_frac_comp[H2] = 0.5
# fs.soec.h2_outlet_translator.properties_out[0.0].mole_frac_comp[H2O] = 0.5
# fs.soec.h2_outlet_translator.properties_out[0.0].temperature = 500
# fs.soec.h2_outlet_translator.properties_out[0.0].pressure = 130000.0
# fs.soec.sweep_heater.control_volume.properties_out[0.0].flow_mol = 8000
# fs.soec.sweep_heater.control_volume.properties_out[0.0].mole_frac_comp[H2O] = 0.5
# fs.soec.sweep_heater.control_volume.properties_out[0.0].mole_frac_comp[O2] = 0.5
# fs.soec.sweep_heater.control_volume.properties_out[0.0].pressure = 130000.0
# fs.soec.h2_inlet_translator.properties_out[0.0].flow_mol = 8000
# fs.soec.h2_inlet_translator.properties_out[0.0].mole_frac_comp[H2] = 0.3333333333333333
# fs.soec.h2_inlet_translator.properties_out[0.0].mole_frac_comp[H2O] = 0.3333333333333333
# fs.soec.h2_inlet_translator.properties_out[0.0].mole_frac_comp[O2] = 0.3333333333333333
# fs.soec.h2_inlet_translator.properties_out[0.0].temperature = 500
# fs.soec.h2_inlet_translator.properties_out[0.0].pressure = 130000.0
# fs.soec.h2_inlet_translator.properties_in[0.0].flow_mol_phase[Vap] = 8000.0
# fs.soec.h2_inlet_translator.properties_in[0.0].mole_frac_phase_comp[Vap,H2] = 0.5
# fs.soec.h2_inlet_translator.properties_in[0.0].mole_frac_phase_comp[Vap,H2O] = 0.5
# fs.soec.h2_inlet_translator.properties_in[0.0].phase_frac[Vap] = 1.0
# fs.soec.h2_inlet_translator.properties_out[0.0].flow_mol_phase[Vap] = 8000.0
# fs.soec.h2_inlet_translator.properties_out[0.0].mole_frac_phase_comp[Vap,H2] = 0.3333333333333333
# fs.soec.h2_inlet_translator.properties_out[0.0].mole_frac_phase_comp[Vap,H2O] = 0.3333333333333333
# fs.soec.h2_inlet_translator.properties_out[0.0].mole_frac_phase_comp[Vap,O2] = 0.3333333333333333
# fs.soec.h2_inlet_translator.properties_out[0.0].phase_frac[Vap] = 1.0
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].flow_mol = 8000
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].mole_frac_comp[H2] = 0.3333333333333333
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].mole_frac_comp[H2O] = 0.3333333333333333
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].mole_frac_comp[O2] = 0.3333333333333333
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].temperature = 500
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].pressure = 130000.0
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].flow_mol = 8000
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].mole_frac_comp[H2] = 0.3333333333333333
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].mole_frac_comp[H2O] = 0.3333333333333333
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].mole_frac_comp[O2] = 0.3333333333333333
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].pressure = 130000.0
# fs.soec.electrolysis_reactor.control_volume.rate_reaction_extent[0.0,h2_cmb] = 0.0
# fs.soec.electrolysis_reactor.control_volume.heat[0.0] = 0.0
# fs.soec.electrolysis_reactor.control_volume.rate_reaction_generation[0.0,Vap,H2] = 0.0
# fs.soec.electrolysis_reactor.control_volume.rate_reaction_generation[0.0,Vap,H2O] = 0.0
# fs.soec.electrolysis_reactor.control_volume.rate_reaction_generation[0.0,Vap,O2] = 0.0
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].flow_mol_phase[Vap] = 8000.0
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,H2] = 0.3333333333333333
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,H2O] = 0.3333333333333333
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,O2] = 0.3333333333333333
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].phase_frac[Vap] = 1.0
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].flow_mol_phase[Vap] = 8000.0
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,H2] = 0.3333333333333333
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,H2O] = 0.3333333333333333
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,O2] = 0.3333333333333333
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].phase_frac[Vap] = 1.0
# fs.soec.o2_separator.mixed_state[0.0].flow_mol = 8000
# fs.soec.o2_separator.mixed_state[0.0].mole_frac_comp[H2] = 0.3333333333333333
# fs.soec.o2_separator.mixed_state[0.0].mole_frac_comp[H2O] = 0.3333333333333333
# fs.soec.o2_separator.mixed_state[0.0].mole_frac_comp[O2] = 0.3333333333333333
# fs.soec.o2_separator.mixed_state[0.0].temperature = 500
# fs.soec.o2_separator.mixed_state[0.0].pressure = 130000.0
# fs.soec.o2_separator.split_fraction[0.0,h2_strm,H2] = 0.5
# fs.soec.o2_separator.split_fraction[0.0,h2_strm,H2O] = 0.5
# fs.soec.o2_separator.split_fraction[0.0,h2_strm,O2] = 0.5
# fs.soec.o2_separator.h2_strm_state[0.0].flow_mol = 8000
# fs.soec.o2_separator.h2_strm_state[0.0].mole_frac_comp[H2] = 0.3333333333333333
# fs.soec.o2_separator.h2_strm_state[0.0].mole_frac_comp[H2O] = 0.3333333333333333
# fs.soec.o2_separator.h2_strm_state[0.0].mole_frac_comp[O2] = 0.3333333333333333
# fs.soec.o2_separator.h2_strm_state[0.0].temperature = 500
# fs.soec.o2_separator.h2_strm_state[0.0].pressure = 130000.0
# fs.soec.o2_separator.o2_strm_state[0.0].flow_mol = 8000
# fs.soec.o2_separator.o2_strm_state[0.0].mole_frac_comp[H2] = 0.3333333333333333
# fs.soec.o2_separator.o2_strm_state[0.0].mole_frac_comp[H2O] = 0.3333333333333333
# fs.soec.o2_separator.o2_strm_state[0.0].mole_frac_comp[O2] = 0.3333333333333333
# fs.soec.o2_separator.o2_strm_state[0.0].temperature = 500
# fs.soec.o2_separator.o2_strm_state[0.0].pressure = 130000.0
# fs.soec.o2_separator.mixed_state[0.0].flow_mol_phase[Vap] = 8000.0
# fs.soec.o2_separator.mixed_state[0.0].mole_frac_phase_comp[Vap,H2] = 0.3333333333333333
# fs.soec.o2_separator.mixed_state[0.0].mole_frac_phase_comp[Vap,H2O] = 0.3333333333333333
# fs.soec.o2_separator.mixed_state[0.0].mole_frac_phase_comp[Vap,O2] = 0.3333333333333333
# fs.soec.o2_separator.mixed_state[0.0].phase_frac[Vap] = 1.0
# fs.soec.o2_separator.h2_strm_state[0.0].flow_mol_phase[Vap] = 8000.0
# fs.soec.o2_separator.h2_strm_state[0.0].mole_frac_phase_comp[Vap,H2] = 0.3333333333333333
# fs.soec.o2_separator.h2_strm_state[0.0].mole_frac_phase_comp[Vap,H2O] = 0.3333333333333333
# fs.soec.o2_separator.h2_strm_state[0.0].mole_frac_phase_comp[Vap,O2] = 0.3333333333333333
# fs.soec.o2_separator.h2_strm_state[0.0].phase_frac[Vap] = 1.0
# fs.soec.o2_separator.o2_strm_state[0.0].flow_mol_phase[Vap] = 8000.0
# fs.soec.o2_separator.o2_strm_state[0.0].mole_frac_phase_comp[Vap,H2] = 0.3333333333333333
# fs.soec.o2_separator.o2_strm_state[0.0].mole_frac_phase_comp[Vap,H2O] = 0.3333333333333333
# fs.soec.o2_separator.o2_strm_state[0.0].mole_frac_phase_comp[Vap,O2] = 0.3333333333333333
# fs.soec.o2_separator.o2_strm_state[0.0].phase_frac[Vap] = 1.0
# fs.soec.h2_outlet_translator.properties_in[0.0].flow_mol = 8000
# fs.soec.h2_outlet_translator.properties_in[0.0].mole_frac_comp[H2] = 0.3333333333333333
# fs.soec.h2_outlet_translator.properties_in[0.0].mole_frac_comp[H2O] = 0.3333333333333333
# fs.soec.h2_outlet_translator.properties_in[0.0].mole_frac_comp[O2] = 0.3333333333333333
# fs.soec.h2_outlet_translator.properties_in[0.0].temperature = 500
# fs.soec.h2_outlet_translator.properties_in[0.0].pressure = 130000.0
# fs.soec.h2_outlet_translator.properties_in[0.0].flow_mol_phase[Vap] = 8000.0
# fs.soec.h2_outlet_translator.properties_in[0.0].mole_frac_phase_comp[Vap,H2] = 0.3333333333333333
# fs.soec.h2_outlet_translator.properties_in[0.0].mole_frac_phase_comp[Vap,H2O] = 0.3333333333333333
# fs.soec.h2_outlet_translator.properties_in[0.0].mole_frac_phase_comp[Vap,O2] = 0.3333333333333333
# fs.soec.h2_outlet_translator.properties_in[0.0].phase_frac[Vap] = 1.0
# fs.soec.h2_outlet_translator.properties_out[0.0].flow_mol_phase[Vap] = 8000.0
# fs.soec.h2_outlet_translator.properties_out[0.0].mole_frac_phase_comp[Vap,H2] = 0.5
# fs.soec.h2_outlet_translator.properties_out[0.0].mole_frac_phase_comp[Vap,H2O] = 0.5
# fs.soec.h2_outlet_translator.properties_out[0.0].phase_frac[Vap] = 1.0
# fs.soec.o2_translator.properties_in[0.0].flow_mol = 8000
# fs.soec.o2_translator.properties_in[0.0].mole_frac_comp[H2] = 0.3333333333333333
# fs.soec.o2_translator.properties_in[0.0].mole_frac_comp[H2O] = 0.3333333333333333
# fs.soec.o2_translator.properties_in[0.0].mole_frac_comp[O2] = 0.3333333333333333
# fs.soec.o2_translator.properties_in[0.0].temperature = 500
# fs.soec.o2_translator.properties_in[0.0].pressure = 130000.0
# fs.soec.o2_translator.properties_out[0.0].flow_mol = 8000
# fs.soec.o2_translator.properties_out[0.0].mole_frac_comp[H2O] = 0.5
# fs.soec.o2_translator.properties_out[0.0].mole_frac_comp[O2] = 1e-19
# fs.soec.o2_translator.properties_out[0.0].temperature = 500
# fs.soec.o2_translator.properties_out[0.0].pressure = 130000.0
# fs.soec.o2_translator.properties_in[0.0].flow_mol_phase[Vap] = 8000.0
# fs.soec.o2_translator.properties_in[0.0].mole_frac_phase_comp[Vap,H2] = 0.3333333333333333
# fs.soec.o2_translator.properties_in[0.0].mole_frac_phase_comp[Vap,H2O] = 0.3333333333333333
# fs.soec.o2_translator.properties_in[0.0].mole_frac_phase_comp[Vap,O2] = 0.3333333333333333
# fs.soec.o2_translator.properties_in[0.0].phase_frac[Vap] = 1.0
# fs.soec.o2_translator.properties_out[0.0].flow_mol_phase[Vap] = 8000.0
# fs.soec.o2_translator.properties_out[0.0].mole_frac_phase_comp[Vap,H2O] = 0.5
# fs.soec.o2_translator.properties_out[0.0].mole_frac_phase_comp[Vap,O2] = 0.5
# fs.soec.o2_translator.properties_out[0.0].phase_frac[Vap] = 1.0
# fs.soec.o2_mixer.o2_strm_state[0.0].flow_mol = 8000
# fs.soec.o2_mixer.o2_strm_state[0.0].mole_frac_comp[H2O] = 0.5
# fs.soec.o2_mixer.o2_strm_state[0.0].mole_frac_comp[O2] = 0.5
# fs.soec.o2_mixer.o2_strm_state[0.0].temperature = 500
# fs.soec.o2_mixer.o2_strm_state[0.0].pressure = 130000.0
# fs.soec.o2_mixer.mixed_state[0.0].flow_mol = 8000
# fs.soec.o2_mixer.mixed_state[0.0].mole_frac_comp[H2O] = 0.5
# fs.soec.o2_mixer.mixed_state[0.0].mole_frac_comp[O2] = 0.5
# fs.soec.o2_mixer.mixed_state[0.0].temperature = 500
# fs.soec.o2_mixer.mixed_state[0.0].pressure = 130000.0
# fs.soec.o2_mixer.sweep_strm_state[0.0].flow_mol_phase[Vap] = 8000.0
# fs.soec.o2_mixer.sweep_strm_state[0.0].mole_frac_phase_comp[Vap,H2O] = 0.5
# fs.soec.o2_mixer.sweep_strm_state[0.0].mole_frac_phase_comp[Vap,O2] = 0.5
# fs.soec.o2_mixer.sweep_strm_state[0.0].phase_frac[Vap] = 1.0
# fs.soec.o2_mixer.o2_strm_state[0.0].flow_mol_phase[Vap] = 8000.0
# fs.soec.o2_mixer.o2_strm_state[0.0].mole_frac_phase_comp[Vap,H2O] = 0.5
# fs.soec.o2_mixer.o2_strm_state[0.0].mole_frac_phase_comp[Vap,O2] = 0.5
# fs.soec.o2_mixer.o2_strm_state[0.0].phase_frac[Vap] = 1.0
# fs.soec.o2_mixer.mixed_state[0.0].flow_mol_phase[Vap] = 8000.0
# fs.soec.o2_mixer.mixed_state[0.0].mole_frac_phase_comp[Vap,H2O] = 0.5
# fs.soec.o2_mixer.mixed_state[0.0].mole_frac_phase_comp[Vap,O2] = 0.5
# fs.soec.o2_mixer.mixed_state[0.0].phase_frac[Vap] = 1.0
# fs.soec.sweep_heater.control_volume.properties_in[0.0].flow_mol = 8000
# fs.soec.sweep_heater.control_volume.properties_in[0.0].mole_frac_comp[H2O] = 0.5
# fs.soec.sweep_heater.control_volume.properties_in[0.0].mole_frac_comp[O2] = 0.5
# fs.soec.sweep_heater.control_volume.properties_in[0.0].temperature = 500
# fs.soec.sweep_heater.control_volume.properties_in[0.0].pressure = 130000.0
# fs.soec.sweep_heater.control_volume.heat[0.0] = 0.0
# fs.soec.sweep_heater.control_volume.properties_in[0.0].flow_mol_phase[Vap] = 8000.0
# fs.soec.sweep_heater.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,H2O] = 0.5
# fs.soec.sweep_heater.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,O2] = 0.5
# fs.soec.sweep_heater.control_volume.properties_in[0.0].phase_frac[Vap] = 1.0
# fs.soec.sweep_heater.control_volume.properties_out[0.0].flow_mol_phase[Vap] = 8000.0
# fs.soec.sweep_heater.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,H2O] = 0.5
# fs.soec.sweep_heater.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,O2] = 0.5
# fs.soec.sweep_heater.control_volume.properties_out[0.0].phase_frac[Vap] = 1.0
#
# Total unfixed: 162

# %%
# Focused: only check soec component
print("--- Unfixed vars in m.fs.soec ---")
for v in m.fs.soec.component_data_objects(pyo.Var, active=True, descend_into=True):
    if not v.fixed:
        print(v)
# Out:
# --- Unfixed vars in m.fs.soec ---
# fs.soec.current[0.0]
# fs.soec.cell_potential[0.0]
# fs.soec.heat[0.0]
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].temperature
# fs.soec.sweep_heater.control_volume.properties_out[0.0].temperature
# fs.soec.h2_outlet_translator.properties_out[0.0].flow_mol
# fs.soec.h2_outlet_translator.properties_out[0.0].mole_frac_comp[H2]
# fs.soec.h2_outlet_translator.properties_out[0.0].mole_frac_comp[H2O]
# fs.soec.h2_outlet_translator.properties_out[0.0].temperature
# fs.soec.h2_outlet_translator.properties_out[0.0].pressure
# fs.soec.sweep_heater.control_volume.properties_out[0.0].flow_mol
# fs.soec.sweep_heater.control_volume.properties_out[0.0].mole_frac_comp[H2O]
# fs.soec.sweep_heater.control_volume.properties_out[0.0].mole_frac_comp[O2]
# fs.soec.sweep_heater.control_volume.properties_out[0.0].pressure
# fs.soec.h2_inlet_translator.properties_out[0.0].flow_mol
# fs.soec.h2_inlet_translator.properties_out[0.0].mole_frac_comp[H2]
# fs.soec.h2_inlet_translator.properties_out[0.0].mole_frac_comp[H2O]
# fs.soec.h2_inlet_translator.properties_out[0.0].mole_frac_comp[O2]
# fs.soec.h2_inlet_translator.properties_out[0.0].temperature
# fs.soec.h2_inlet_translator.properties_out[0.0].pressure
# fs.soec.h2_inlet_translator.properties_in[0.0].flow_mol_phase[Vap]
# fs.soec.h2_inlet_translator.properties_in[0.0].mole_frac_phase_comp[Vap,H2]
# fs.soec.h2_inlet_translator.properties_in[0.0].mole_frac_phase_comp[Vap,H2O]
# fs.soec.h2_inlet_translator.properties_in[0.0].phase_frac[Vap]
# fs.soec.h2_inlet_translator.properties_out[0.0].flow_mol_phase[Vap]
# fs.soec.h2_inlet_translator.properties_out[0.0].mole_frac_phase_comp[Vap,H2]
# fs.soec.h2_inlet_translator.properties_out[0.0].mole_frac_phase_comp[Vap,H2O]
# fs.soec.h2_inlet_translator.properties_out[0.0].mole_frac_phase_comp[Vap,O2]
# fs.soec.h2_inlet_translator.properties_out[0.0].phase_frac[Vap]
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].flow_mol
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].mole_frac_comp[H2]
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].mole_frac_comp[H2O]
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].mole_frac_comp[O2]
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].temperature
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].pressure
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].flow_mol
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].mole_frac_comp[H2]
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].mole_frac_comp[H2O]
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].mole_frac_comp[O2]
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].pressure
# fs.soec.electrolysis_reactor.control_volume.rate_reaction_extent[0.0,h2_cmb]
# fs.soec.electrolysis_reactor.control_volume.heat[0.0]
# fs.soec.electrolysis_reactor.control_volume.rate_reaction_generation[0.0,Vap,H2]
# fs.soec.electrolysis_reactor.control_volume.rate_reaction_generation[0.0,Vap,H2O]
# fs.soec.electrolysis_reactor.control_volume.rate_reaction_generation[0.0,Vap,O2]
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].flow_mol_phase[Vap]
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,H2]
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,H2O]
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,O2]
# fs.soec.electrolysis_reactor.control_volume.properties_in[0.0].phase_frac[Vap]
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].flow_mol_phase[Vap]
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,H2]
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,H2O]
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,O2]
# fs.soec.electrolysis_reactor.control_volume.properties_out[0.0].phase_frac[Vap]
# fs.soec.o2_separator.mixed_state[0.0].flow_mol
# fs.soec.o2_separator.mixed_state[0.0].mole_frac_comp[H2]
# fs.soec.o2_separator.mixed_state[0.0].mole_frac_comp[H2O]
# fs.soec.o2_separator.mixed_state[0.0].mole_frac_comp[O2]
# fs.soec.o2_separator.mixed_state[0.0].temperature
# fs.soec.o2_separator.mixed_state[0.0].pressure
# fs.soec.o2_separator.split_fraction[0.0,h2_strm,H2]
# fs.soec.o2_separator.split_fraction[0.0,h2_strm,H2O]
# fs.soec.o2_separator.split_fraction[0.0,h2_strm,O2]
# fs.soec.o2_separator.h2_strm_state[0.0].flow_mol
# fs.soec.o2_separator.h2_strm_state[0.0].mole_frac_comp[H2]
# fs.soec.o2_separator.h2_strm_state[0.0].mole_frac_comp[H2O]
# fs.soec.o2_separator.h2_strm_state[0.0].mole_frac_comp[O2]
# fs.soec.o2_separator.h2_strm_state[0.0].temperature
# fs.soec.o2_separator.h2_strm_state[0.0].pressure
# fs.soec.o2_separator.o2_strm_state[0.0].flow_mol
# fs.soec.o2_separator.o2_strm_state[0.0].mole_frac_comp[H2]
# fs.soec.o2_separator.o2_strm_state[0.0].mole_frac_comp[H2O]
# fs.soec.o2_separator.o2_strm_state[0.0].mole_frac_comp[O2]
# fs.soec.o2_separator.o2_strm_state[0.0].temperature
# fs.soec.o2_separator.o2_strm_state[0.0].pressure
# fs.soec.o2_separator.mixed_state[0.0].flow_mol_phase[Vap]
# fs.soec.o2_separator.mixed_state[0.0].mole_frac_phase_comp[Vap,H2]
# fs.soec.o2_separator.mixed_state[0.0].mole_frac_phase_comp[Vap,H2O]
# fs.soec.o2_separator.mixed_state[0.0].mole_frac_phase_comp[Vap,O2]
# fs.soec.o2_separator.mixed_state[0.0].phase_frac[Vap]
# fs.soec.o2_separator.h2_strm_state[0.0].flow_mol_phase[Vap]
# fs.soec.o2_separator.h2_strm_state[0.0].mole_frac_phase_comp[Vap,H2]
# fs.soec.o2_separator.h2_strm_state[0.0].mole_frac_phase_comp[Vap,H2O]
# fs.soec.o2_separator.h2_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
# fs.soec.o2_separator.h2_strm_state[0.0].phase_frac[Vap]
# fs.soec.o2_separator.o2_strm_state[0.0].flow_mol_phase[Vap]
# fs.soec.o2_separator.o2_strm_state[0.0].mole_frac_phase_comp[Vap,H2]
# fs.soec.o2_separator.o2_strm_state[0.0].mole_frac_phase_comp[Vap,H2O]
# fs.soec.o2_separator.o2_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
# fs.soec.o2_separator.o2_strm_state[0.0].phase_frac[Vap]
# fs.soec.h2_outlet_translator.properties_in[0.0].flow_mol
# fs.soec.h2_outlet_translator.properties_in[0.0].mole_frac_comp[H2]
# fs.soec.h2_outlet_translator.properties_in[0.0].mole_frac_comp[H2O]
# fs.soec.h2_outlet_translator.properties_in[0.0].mole_frac_comp[O2]
# fs.soec.h2_outlet_translator.properties_in[0.0].temperature
# fs.soec.h2_outlet_translator.properties_in[0.0].pressure
# fs.soec.h2_outlet_translator.properties_in[0.0].flow_mol_phase[Vap]
# fs.soec.h2_outlet_translator.properties_in[0.0].mole_frac_phase_comp[Vap,H2]
# fs.soec.h2_outlet_translator.properties_in[0.0].mole_frac_phase_comp[Vap,H2O]
# fs.soec.h2_outlet_translator.properties_in[0.0].mole_frac_phase_comp[Vap,O2]
# fs.soec.h2_outlet_translator.properties_in[0.0].phase_frac[Vap]
# fs.soec.h2_outlet_translator.properties_out[0.0].flow_mol_phase[Vap]
# fs.soec.h2_outlet_translator.properties_out[0.0].mole_frac_phase_comp[Vap,H2]
# fs.soec.h2_outlet_translator.properties_out[0.0].mole_frac_phase_comp[Vap,H2O]
# fs.soec.h2_outlet_translator.properties_out[0.0].phase_frac[Vap]
# fs.soec.o2_translator.properties_in[0.0].flow_mol
# fs.soec.o2_translator.properties_in[0.0].mole_frac_comp[H2]
# fs.soec.o2_translator.properties_in[0.0].mole_frac_comp[H2O]
# fs.soec.o2_translator.properties_in[0.0].mole_frac_comp[O2]
# fs.soec.o2_translator.properties_in[0.0].temperature
# fs.soec.o2_translator.properties_in[0.0].pressure
# fs.soec.o2_translator.properties_out[0.0].flow_mol
# fs.soec.o2_translator.properties_out[0.0].mole_frac_comp[H2O]
# fs.soec.o2_translator.properties_out[0.0].mole_frac_comp[O2]
# fs.soec.o2_translator.properties_out[0.0].temperature
# fs.soec.o2_translator.properties_out[0.0].pressure
# fs.soec.o2_translator.properties_in[0.0].flow_mol_phase[Vap]
# fs.soec.o2_translator.properties_in[0.0].mole_frac_phase_comp[Vap,H2]
# fs.soec.o2_translator.properties_in[0.0].mole_frac_phase_comp[Vap,H2O]
# fs.soec.o2_translator.properties_in[0.0].mole_frac_phase_comp[Vap,O2]
# fs.soec.o2_translator.properties_in[0.0].phase_frac[Vap]
# fs.soec.o2_translator.properties_out[0.0].flow_mol_phase[Vap]
# fs.soec.o2_translator.properties_out[0.0].mole_frac_phase_comp[Vap,H2O]
# fs.soec.o2_translator.properties_out[0.0].mole_frac_phase_comp[Vap,O2]
# fs.soec.o2_translator.properties_out[0.0].phase_frac[Vap]
# fs.soec.o2_mixer.o2_strm_state[0.0].flow_mol
# fs.soec.o2_mixer.o2_strm_state[0.0].mole_frac_comp[H2O]
# fs.soec.o2_mixer.o2_strm_state[0.0].mole_frac_comp[O2]
# fs.soec.o2_mixer.o2_strm_state[0.0].temperature
# fs.soec.o2_mixer.o2_strm_state[0.0].pressure
# fs.soec.o2_mixer.mixed_state[0.0].flow_mol
# fs.soec.o2_mixer.mixed_state[0.0].mole_frac_comp[H2O]
# fs.soec.o2_mixer.mixed_state[0.0].mole_frac_comp[O2]
# fs.soec.o2_mixer.mixed_state[0.0].temperature
# fs.soec.o2_mixer.mixed_state[0.0].pressure
# fs.soec.o2_mixer.sweep_strm_state[0.0].flow_mol_phase[Vap]
# fs.soec.o2_mixer.sweep_strm_state[0.0].mole_frac_phase_comp[Vap,H2O]
# fs.soec.o2_mixer.sweep_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
# fs.soec.o2_mixer.sweep_strm_state[0.0].phase_frac[Vap]
# fs.soec.o2_mixer.o2_strm_state[0.0].flow_mol_phase[Vap]
# fs.soec.o2_mixer.o2_strm_state[0.0].mole_frac_phase_comp[Vap,H2O]
# fs.soec.o2_mixer.o2_strm_state[0.0].mole_frac_phase_comp[Vap,O2]
# fs.soec.o2_mixer.o2_strm_state[0.0].phase_frac[Vap]
# fs.soec.o2_mixer.mixed_state[0.0].flow_mol_phase[Vap]
# fs.soec.o2_mixer.mixed_state[0.0].mole_frac_phase_comp[Vap,H2O]
# fs.soec.o2_mixer.mixed_state[0.0].mole_frac_phase_comp[Vap,O2]
# fs.soec.o2_mixer.mixed_state[0.0].phase_frac[Vap]
# fs.soec.sweep_heater.control_volume.properties_in[0.0].flow_mol
# fs.soec.sweep_heater.control_volume.properties_in[0.0].mole_frac_comp[H2O]
# fs.soec.sweep_heater.control_volume.properties_in[0.0].mole_frac_comp[O2]
# fs.soec.sweep_heater.control_volume.properties_in[0.0].temperature
# fs.soec.sweep_heater.control_volume.properties_in[0.0].pressure
# fs.soec.sweep_heater.control_volume.heat[0.0]
# fs.soec.sweep_heater.control_volume.properties_in[0.0].flow_mol_phase[Vap]
# fs.soec.sweep_heater.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,H2O]
# fs.soec.sweep_heater.control_volume.properties_in[0.0].mole_frac_phase_comp[Vap,O2]
# fs.soec.sweep_heater.control_volume.properties_in[0.0].phase_frac[Vap]
# fs.soec.sweep_heater.control_volume.properties_out[0.0].flow_mol_phase[Vap]
# fs.soec.sweep_heater.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,H2O]
# fs.soec.sweep_heater.control_volume.properties_out[0.0].mole_frac_phase_comp[Vap,O2]
# fs.soec.sweep_heater.control_volume.properties_out[0.0].phase_frac[Vap]

# %%
# Fix the 3 remaining top-level DOFs
# Option A: Fix cell_potential and heat (let current be computed)
m.fs.soec.cell_potential[0].fix(1.28)   # V — mid-range operating point
m.fs.soec.heat[0].fix(0.0)              # W — adiabatic assumption

# Leave water_utilization fixed at 0.80 (already done)
# current[0] will be computed by the solver

from idaes.core.util.model_statistics import degrees_of_freedom
print("Degrees of freedom:", degrees_of_freedom(m))  # Must print 0
# Out:
# Degrees of freedom: 1

# %%
# Find the last remaining unfixed top-level variable
print("--- Remaining top-level free vars ---")
for name in ["current", "cell_potential", "heat", "water_utilization", "scaling_factor"]:
    try:
        v = getattr(m.fs.soec, name)[0]
        print(f"{name}: fixed={v.fixed}, value={v.value}")
    except:
        pass
# Out:
# --- Remaining top-level free vars ---
# current: fixed=False, value=0
# cell_potential: fixed=True, value=1.28
# heat: fixed=True, value=0.0
# water_utilization: fixed=True, value=0.8

# %%
# Fix current — this closes the last DOF
# cell_potential_eqn will be satisfied by the solver
# Unfix cell_potential so it's computed, fix current instead
m.fs.soec.cell_potential[0].unfix()
m.fs.soec.current[0].fix(50000)  # 50,000 A starting point

from idaes.core.util.model_statistics import degrees_of_freedom
print("DOF:", degrees_of_freedom(m))  # Must be 0
# Out:
# DOF: 1

# %%
# Fix current to match your target operating point
# For 1.61 A/cm² with 900 cells × 360 cm²:
# current = 1.61 × 900 × 360 = 521,640 A
# Start conservative — use a lower value first
m.fs.soec.current[0].fix(50000)   # 50 kA starting point

from idaes.core.util.model_statistics import degrees_of_freedom
print("Degrees of freedom:", degrees_of_freedom(m))  # Must print 0
# Out:
# Degrees of freedom: 1

# %%
# Precisely identify the ONE remaining free variable
# by checking all top-level soec vars for fixed status
print("=== All top-level SOEC scalar/indexed vars ===")
import pyomo.environ as pyo

for comp in m.fs.soec.component_objects(pyo.Var, active=True, descend_into=False):
    for idx, v in comp.items():
        if not v.fixed:
            print(f"UNFIXED: {comp.name}[{idx}] = {v.value}")

print("\n--- Also checking scaling_factor ---")
try:
    sf = m.fs.soec.scaling_factor
    for k, v in sf.items():
        print(f"  scaling_factor[{k}] = {v}")
except:
    print("  no scaling_factor found")
# Out:
# === All top-level SOEC scalar/indexed vars ===
# UNFIXED: fs.soec.cell_potential[0.0] = 1.28
# UNFIXED: fs.soec.hydrogen_side_outlet_temperature[0.0] = 500
# UNFIXED: fs.soec.oxygen_side_outlet_temperature[0.0] = 500
# UNFIXED: fs.soec._flow_mol_hydrogen_side_outlet_ref[0.0] = 8000
# UNFIXED: fs.soec._mole_frac_comp_hydrogen_side_outlet_ref[(0.0, 'H2')] = 0.5
# UNFIXED: fs.soec._mole_frac_comp_hydrogen_side_outlet_ref[(0.0, 'H2O')] = 0.5
# UNFIXED: fs.soec._temperature_hydrogen_side_outlet_ref[0.0] = 500
# UNFIXED: fs.soec._pressure_hydrogen_side_outlet_ref[0.0] = 130000.0
# UNFIXED: fs.soec._flow_mol_oxygen_side_outlet_ref[0.0] = 8000
# UNFIXED: fs.soec._mole_frac_comp_oxygen_side_outlet_ref[(0.0, 'H2O')] = 0.5
# UNFIXED: fs.soec._mole_frac_comp_oxygen_side_outlet_ref[(0.0, 'O2')] = 0.5
# UNFIXED: fs.soec._temperature_oxygen_side_outlet_ref[0.0] = 500
# UNFIXED: fs.soec._pressure_oxygen_side_outlet_ref[0.0] = 130000.0
#
# --- Also checking scaling_factor ---
#   scaling_factor[fs.soec.heat] = 1e-05
#   scaling_factor[fs.soec.heat[0.0]] = 1e-05
#   scaling_factor[fs.soec.current] = 1e-06
#   scaling_factor[fs.soec.current[0.0]] = 1e-06

# %%
# Clean reset — establish correct DOF=0 state
# Strategy: fix cell_potential as design input, unfix current (it's computed)

m.fs.soec.current[0].unfix()          # current is an OUTPUT — let solver compute it
m.fs.soec.cell_potential[0].fix(1.28) # cell voltage is the DESIGN INPUT

from idaes.core.util.model_statistics import degrees_of_freedom
print("DOF:", degrees_of_freedom(m))  # Must be 0
# Out:
# DOF: 1

# %%
# Find the ONE variable causing DOF=1 by checking sub-units
import pyomo.environ as pyo
from idaes.core.util.model_statistics import degrees_of_freedom

# Check DOF of each sub-unit individually
subunits = [
    "electrolysis_reactor",
    "sweep_heater", 
    "o2_separator",
    "o2_mixer",
    "h2_inlet_translator",
    "h2_outlet_translator",
    "o2_translator"
]

for name in subunits:
    try:
        unit = getattr(m.fs.soec, name)
        dof = degrees_of_freedom(unit)
        if dof != 0:
            print(f"*** DOF={dof} in: m.fs.soec.{name}")
        else:
            print(f"    DOF=0 OK: {name}")
    except Exception as e:
        print(f"    Could not check {name}: {e}")
# Out:
# *** DOF=8 in: m.fs.soec.electrolysis_reactor
# *** DOF=6 in: m.fs.soec.sweep_heater
# *** DOF=6 in: m.fs.soec.o2_separator
# *** DOF=4 in: m.fs.soec.o2_mixer
#     DOF=0 OK: h2_inlet_translator
# *** DOF=6 in: m.fs.soec.h2_outlet_translator
# *** DOF=6 in: m.fs.soec.o2_translator

# %%
# The sweep_heater outlet temperature is the missing specification
# It controls the oxygen-side inlet temperature to the electrolysis reactor
m.fs.soec.sweep_heater.outlet.temperature[0].fix(1073.15)  # 800°C = same as inlet

from idaes.core.util.model_statistics import degrees_of_freedom
print("DOF:", degrees_of_freedom(m))
# Out:
# DOF: 0

# %%
from idaes.core.solvers import get_solver
from pyomo.environ import value

solver = get_solver()

try:
    m.fs.soec.initialize(outlvl=0)
except Exception as e:
    print(f"Init note: {e}")

result = solver.solve(m, tee=False)

print("\n=== SOLVE RESULT ===")
print("Status:   ", result.solver.termination_condition)
print("V_cell:   ", round(value(m.fs.soec.cell_potential[0]), 4), "V")
print("Current:  ", round(value(m.fs.soec.current[0]), 1), "A")
print("T_h2_out: ", round(value(m.fs.soec.hydrogen_side_outlet_temperature[0]), 2), "K")
print("T_o2_out: ", round(value(m.fs.soec.oxygen_side_outlet_temperature[0]), 2), "K")
dT = (value(m.fs.soec.hydrogen_side_outlet_temperature[0]) -
      value(m.fs.soec.oxygen_side_outlet_temperature[0]))
print("dT:       ", round(dT, 2), "K")
j = value(m.fs.soec.current[0]) / (900 * 360)
print("j:        ", round(j, 4), "A/cm²")
print("Safe:     ", "YES" if (0.9 <= value(m.fs.soec.cell_potential[0]) <= 1.3 
                               and abs(dT) <= 20) else "NO")
# Out:
# 2026-03-27 20:22:33 [INFO] idaes.init.fs.soec.h2_inlet_translator.properties_in: Starting initialization
# 2026-03-27 20:22:46 [INFO] idaes.init.fs.soec.h2_inlet_translator.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:46 [INFO] idaes.init.fs.soec.h2_inlet_translator.properties_out: Starting initialization
# 2026-03-27 20:22:46 [INFO] idaes.init.fs.soec.h2_inlet_translator.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:46 [INFO] idaes.init.fs.soec.h2_inlet_translator.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:46 [INFO] idaes.init.fs.soec.h2_inlet_translator: Initialization Complete optimal - Optimal Solution Found.
# 2026-03-27 20:22:46 [INFO] idaes.init.fs.soec.electrolysis_reactor.control_volume.properties_in: Starting initialization
# WARNING: model contains export suffix 'scaling_factor' that contains 1 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
# 2026-03-27 20:22:46 [INFO] idaes.init.fs.soec.electrolysis_reactor.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:46 [INFO] idaes.init.fs.soec.electrolysis_reactor.control_volume.properties_out: Starting initialization
# WARNING: model contains export suffix 'scaling_factor' that contains 1 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
# 2026-03-27 20:22:46 [INFO] idaes.init.fs.soec.electrolysis_reactor.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:46 [INFO] idaes.init.fs.soec.electrolysis_reactor.control_volume.reactions: Initialization Complete.
# 2026-03-27 20:22:46 [INFO] idaes.init.fs.soec.electrolysis_reactor.control_volume: Initialization Complete
# WARNING: model contains export suffix 'scaling_factor' that contains 2 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.electrolysis_reactor: Initialization Complete: optimal - Optimal Solution Found
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.o2_separator.mixed_state: Starting initialization
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.o2_separator.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.o2_separator.h2_strm_state: Starting initialization
# WARNING: model contains export suffix 'scaling_factor' that contains 1 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.o2_separator.h2_strm_state: Property initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.o2_separator.h2_strm_state: Property package initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.o2_separator.o2_strm_state: Starting initialization
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.o2_separator.o2_strm_state: Property initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.o2_separator.o2_strm_state: Property package initialization: optimal - Optimal Solution Found.
# WARNING: model contains export suffix 'scaling_factor' that contains 1 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.o2_separator: Initialization Step 2 Complete: optimal - Optimal Solution Found
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.h2_outlet_translator.properties_in: Starting initialization
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.h2_outlet_translator.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.h2_outlet_translator.properties_out: Starting initialization
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.h2_outlet_translator.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.h2_outlet_translator.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.h2_outlet_translator: Initialization Complete optimal - Optimal Solution Found.
# 2026-03-27 20:22:47 [INFO] idaes.init.fs.soec.o2_translator.properties_in: Starting initialization
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.o2_translator.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.o2_translator.properties_out: Starting initialization
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.o2_translator.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.o2_translator.properties_out: Property package initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.o2_translator: Initialization Complete optimal - Optimal Solution Found.
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.o2_mixer.sweep_strm_state: Starting initialization
# WARNING: model contains export suffix 'scaling_factor' that contains 1 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.o2_mixer.sweep_strm_state: Property initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.o2_mixer.o2_strm_state: Starting initialization
# WARNING: model contains export suffix 'scaling_factor' that contains 1 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.o2_mixer.o2_strm_state: Property initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.o2_mixer.mixed_state: Starting initialization
# WARNING: model contains export suffix 'scaling_factor' that contains 1 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.o2_mixer.mixed_state: Property initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.o2_mixer.mixed_state: Property package initialization: optimal - Optimal Solution Found.
# WARNING: model contains export suffix 'scaling_factor' that contains 3 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.o2_mixer: Initialization Complete: optimal - Optimal Solution Found
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.sweep_heater.control_volume.properties_in: Starting initialization
# WARNING: model contains export suffix 'scaling_factor' that contains 1 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.sweep_heater.control_volume.properties_in: Property initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.sweep_heater.control_volume.properties_out: Starting initialization
# WARNING: model contains export suffix 'scaling_factor' that contains 1 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.sweep_heater.control_volume.properties_out: Property initialization: optimal - Optimal Solution Found.
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.sweep_heater.control_volume: Initialization Complete
# WARNING: model contains export suffix 'scaling_factor' that contains 2 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
# 2026-03-27 20:22:48 [INFO] idaes.init.fs.soec.sweep_heater: Initialization Complete: optimal - Optimal Solution Found
# WARNING: model contains export suffix 'scaling_factor' that contains 1
# component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'scaling_factor' that contains 8 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
# WARNING: model contains export suffix 'scaling_factor' that contains 1
# component keys that are not exported as part of the NL file.  Skipping.
# WARNING: model contains export suffix 'scaling_factor' that contains 8 keys
# that are not Var, Constraint, Objective, or the model.  Skipping.
#
# === SOLVE RESULT ===
# Status:    optimal
# V_cell:    1.28 V
# Current:   13893.9 A
# T_h2_out:  1043.89 K
# T_o2_out:  1073.15 K
# dT:        -29.26 K
# j:         0.0429 A/cm²
# Safe:      NO

# %%
# Cell — Checkpoint: save the working fixed-point state
import pickle
from pyomo.environ import value

checkpoint = {
    "description": "Single-point solve validated. DOF=0, Status=optimal.",
    "fixed_inputs": {
        "hydrogen_side_inlet.flow_mol": 0.10,
        "hydrogen_side_inlet.temperature": 1073.15,
        "hydrogen_side_inlet.pressure": 1.5e5,
        "hydrogen_side_inlet.mole_frac_H2O": 0.90,
        "hydrogen_side_inlet.mole_frac_H2": 0.10,
        "oxygen_side_inlet.flow_mol": 0.10,
        "oxygen_side_inlet.temperature": 1073.15,
        "oxygen_side_inlet.pressure": 1.5e5,
        "oxygen_side_inlet.mole_frac_O2": 0.21,
        "oxygen_side_inlet.mole_frac_H2O": 0.79,
        "water_utilization": 0.80,
        "cell_potential": 1.28,
        "heat": 0.0,
        "sweep_heater_outlet_temperature": 1073.15,
    },
    "validated_outputs": {
        "V_cell_V":    round(value(m.fs.soec.cell_potential[0]), 4),
        "current_A":   round(value(m.fs.soec.current[0]), 1),
        "T_h2_out_K":  round(value(m.fs.soec.hydrogen_side_outlet_temperature[0]), 2),
        "T_o2_out_K":  round(value(m.fs.soec.oxygen_side_outlet_temperature[0]), 2),
        "dT_K":        round(value(m.fs.soec.hydrogen_side_outlet_temperature[0]) -
                             value(m.fs.soec.oxygen_side_outlet_temperature[0]), 2),
        "j_Acm2":      round(value(m.fs.soec.current[0]) / (900 * 360), 6),
    }
}

with open("dt_checkpoint_single_solve.pkl", "wb") as f:
    pickle.dump(checkpoint, f)

print("=== CHECKPOINT SAVED ===")
for k, v in checkpoint["validated_outputs"].items():
    print(f"  {k}: {v}")
print("\nSafe to proceed to Step 5 sweep.")
# Out:
# === CHECKPOINT SAVED ===
#   V_cell_V: 1.28
#   current_A: 13893.9
#   T_h2_out_K: 1043.89
#   T_o2_out_K: 1073.15
#   dT_K: -29.26
#   j_Acm2: 0.042882
#
# Safe to proceed to Step 5 sweep.
