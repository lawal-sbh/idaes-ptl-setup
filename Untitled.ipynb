# %%
import os
print(os.getcwd())
print(os.listdir('.'))
# Out:
# C:\Windows\System32\idaes-ptl-setup
# ['.git', '.gitignore', '.ipynb_checkpoints', 'dt_checkpoint_single_solve.pkl', 'LICENSE', 'mapirl_dt_v1.ipynb', 'miniconda.exe', 'pinn_training_data.csv', 'pinn_training_data_v1_25pts.csv', 'README.md', 'setup.bat', 'setup.md', 'smoke_test.ipynb', 'Untitled.ipynb']
